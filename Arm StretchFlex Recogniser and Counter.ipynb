# %%
fivearray = np.array(5, float)
fivearray
np.linalg.norm(fivearray)
# Out:
# 5.0

# %%
np.linalg.norm(np.array([1,2,3]))
# Out:
# 3.7416573867739413

# %%
import cv2
import numpy as np
import mediapipe as mp
import time
from collections import deque

# ----------------- CONFIG -----------------
CAM_INDEX = 0 # choose camera
DISPLAY_MIRROR = True  # <- show mirrored preview, but keep logic non-mirrored

# Angle thresholds (degrees)
ANGLE_UP = 75
ANGLE_DOWN = 150

# Smoothing
ANGLE_EMA_ALPHA = 0.2
USE_MEDIAN_WINDOW = 5

# Debounce
HOLD_FRAMES = 2

# https://medium.com/@codetrade/implementation-of-human-pose-estimation-using-mediapipe-23a57968356b
# To initialize the pose estimation object we will call the pose class from mediapipe.solutions.pose and create an object 
# named mp_pose. You can replace the class name as per your requirements.
mp_pose = mp.solutions.pose


####################################################################################################################################
def angle_between(a, b, c):
    # a for shoulder, b for elbow, c for wrist
    # a, b, c are (x, y) coordinates (coordinate pairs) respectively, convert them to a vector of two elements respectively,
    # convert them to vectors so we can perform vector calculus
    a = np.array(a, float); b = np.array(b, float); c = np.array(c, float)
    print("shoulder = " + str(a) + ", elbow = " + str(b) + ", wrist = " + str(c))
    
    # calculate difference in coordinate
    ba = a - b; bc = c - b
    print("shoulder - elbow = " + str(ba) + ", elbow - wrist = " + str(bc))

    # np.linalg.norm(np.array[x, y]) = sqrt(x^2 + y^2)
    # find hypotenuse using pythagorean theorem
    # + 1e-8 to avoid division by 0 in cosang
    n1 = np.linalg.norm(ba) + 1e-8; n2 = np.linalg.norm(bc) + 1e-8
    print("hypotenuse (shoulder - elbow) = " + str(n1) + ", hypotenuse (elbow - wrist) = " + str(n2))
    
    # np.clip limits the values in an array
    # e.g. if interval [0, 1] is specified, then numbers smaller than 0 becomes 0, numbers large than 1 becomes 1.
    # right here, we calculate (np.dot(ba, bc))/(n1 * n2), subjected to clip interval [-1.0, 1.0]
    '''
    Using dot-product identity, 
    ba ⋅ bc = |ba||bc|cos(θ) => cos(θ) = (ba ⋅ bc)/(|ba||bc|)
    to get angle between two vectors.
    
    |u| = sqrt(u_x^2 + u_y^2)
    u.v = (u_x * v_x) + (u_y + v_y) = [u_x, u_y] ⋅ [v_x, v_y]^T
    '''
    cosang = np.clip(np.dot(ba, bc) / (n1 * n2), -1.0, 1.0)
    print("cosang = " + str(cosang))

    # cos(theta) = adjacent/hypotenuse
    # theta = arccos(adjacent/hypotenuse)
    print("theta = " + str(np.arccos(cosang)))
    return np.degrees(np.arccos(cosang))

####################################################################################################################################3
def get_arm_landmarks_xy(landmarks, w, h, which):

    # https://ai.google.dev/edge/mediapipe/solutions/vision/pose_landmarker
    # The MediaPipe Pose Landmarker task lets you detect landmarks of human bodies in an image or video. 
    L = mp_pose.PoseLandmark # 'L' for Landmark
   
    if which == "right":
        # Basically, something like "L.RIGHT_SHOULDER.value" is just a predefined index of a body landmark in PoseLandmark.
        s, e, wri = L.RIGHT_SHOULDER.value, L.RIGHT_ELBOW.value, L.RIGHT_WRIST.value
        print("L.RIGHT_SHOULDER.value = " + str(L.RIGHT_SHOULDER.value) + ", L.RIGHT_ELBOW.value = " +  str(L.RIGHT_ELBOW.value)
             + ", L.RIGHT_WRIST.value = " + str(L.RIGHT_WRIST.value))
    else:
        s, e, wri = L.LEFT_SHOULDER.value, L.LEFT_ELBOW.value, L.LEFT_WRIST.value
        print("L.LEFT_SHOULDER.value = " + str(L.LEFT_SHOULDER.value) + ", L.LEFT_ELBOW.value = " +  str(L.LEFT_ELBOW.value)
             + ", L.LEFT_WRIST.value = " + str(L.LEFT_WRIST.value))

    # get the 3D coordinates and light visibility index for the landmarks of shoulder, elbow, wrist
    S, E, W = landmarks[s], landmarks[e], landmarks[wri]
    print("3D Coordinates and Visibility of Landmarks: " + "S = " + str(S) + ", E = " + str(E) + ", W = " + str(W))

    # function_name = lambda <argument>: (<operations>)
    to_xy = lambda lm: (lm.x * w, lm.y * h)
    # Basically, extracts the (x, y) coordinates, multiply x by w and multiply y by h to convert
    '''
    MediaPipe gives landmark coordinates normalized to the image:
    lm.x and lm.y are floats ~in [0, 1] measured as a fraction of the frame width/height (origin at the top-left, +x to the right, +y downward).

    Quick example:
    If your frame is 1280×720 and a wrist has (lm.x=0.25, lm.y=0.50), then
    x_px = 0.25 * 1280 = 320
    y_px = 0.50 * 720 = 360
    → pixel ≈ (320, 360).
    '''
    
    return to_xy(S), to_xy(E), to_xy(W)
    
####################################################################################################################################
def mirror_xy(pt, width):
    """Mirror an (x,y) pixel coordinate for drawing on the mirrored view."""
    x, y = pt
    return (int(width - 1 - x), int(y))
'''
- Images use pixel indices x = 0, ..., width-1 from left → right.
- A horizontal mirror maps each x to its symmetric partner:
  x′ = (width − 1) − x
    So:
    ⋅ Left edge x=0 → x' = width-1 (right edge)
    ⋅ Right edge x=width-1 → x' = 0 (left edge)
    ⋅ Centerline x=(width-1)/2 stays the same
- y is unchanged because we’re only flipping left↔right.
- int(...) ensures the result is an integer pixel coordinate for OpenCV drawing.
'''

####################################################################################################################################
class ArmTracker:

    # constructor for ArmTracker class object
    '''
    __init__ method in Python is a constructor. 
    Basically you call a constructor method to create its class object.
    ____________________________________________
    Example: 
    
    class Person:
        def __init__(self, name, age):
            self.name = name
            self.age = age

    p1 = Person("Alice", 30)
    p2 = Person("Bob", 25)
    
    print(p1.name, p1.age)  # Alice 30
    print(p2.name, p2.age)  # Bob 25
    ____________________________________________
    
    '''
    def __init__(self, name): # Basically name is either the label "Left" or "Right"
        self.name = name
        self.state = "down"
        self.reps = 0 # count number of reps
        self.ema = None
        self.hist = deque(maxlen=USE_MEDIAN_WINDOW if USE_MEDIAN_WINDOW > 0 else 1)
        self.up_hold = 0
        self.down_hold = 0
        self.angle_vis_deg = None
        self.elbow_xy = None

    def update(self, raw_angle_deg, elbow_xy):
        # Add the newest elbow angle (in degrees) into a short rolling list (self.hist).
        self.hist.append(raw_angle_deg)

        # If median filtering is enabled, replace the raw angle with the median of the last N 
        # angles (kills 1-frame glitches). Otherwise, just use the raw value.
        angle_deg = float(np.median(self.hist)) if USE_MEDIAN_WINDOW > 0 else raw_angle_deg


        '''
        Smooth the (possibly median-filtered) angle with an Exponential Moving Average (EMA):
        first frame: set EMA to the current angle,
        later frames: blend current angle with previous EMA using ANGLE_EMA_ALPHA (α).
        bigger α → reacts faster, less smooth; smaller α → smoother, slower.
        Store the smoothed angle in angle_vis_deg (used for logic and for drawing on screen).
        Remember the elbow pixel location (so you can put the angle text near it).
        '''
        self.ema = angle_deg if self.ema is None else ANGLE_EMA_ALPHA * angle_deg + 
                   (1-ANGLE_EMA_ALPHA) * self.ema
        self.angle_vis_deg = self.ema
        self.elbow_xy = elbow_xy


        
        '''
        If the smoothed angle is large enough (≥ ANGLE_DOWN, i.e., arm looks extended), 
        increase down_hold.
        Otherwise, reset down_hold.
        Those “hold” counters are a debounce: require the condition to be true for several 
        frames (HOLD_FRAMES) so tiny jitters don’t flip state.
        '''
        if self.angle_vis_deg <= ANGLE_UP: self.up_hold += 1
        else: self.up_hold = 0

        if self.angle_vis_deg >= ANGLE_DOWN: self.down_hold += 1
        else: self.down_hold = 0

        if self.state == "down" and self.up_hold >= HOLD_FRAMES:
            self.state = "up"
        elif self.state == "up" and self.down_hold >= HOLD_FRAMES:
            self.state = "down"; self.reps += 1

####################################################################################################################################
def main():
    cap = cv2.VideoCapture(CAM_INDEX)
    if not cap.isOpened():
        print("Could not open webcam."); return

    pose = mp_pose.Pose(
        static_image_mode=False, model_complexity=1,
        smooth_landmarks=True, enable_segmentation=False,
        min_detection_confidence=0.5, min_tracking_confidence=0.5
    )

    left = ArmTracker("Left")
    right = ArmTracker("Right")
    t_prev = time.time()

    print("Press 'q' to quit.")
    while True:
        ok, frame_bgr = cap.read()
        if not ok: break

        h, w = frame_bgr.shape[:2]

        # process on the real non-mirrored frame
        rgb = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2RGB)
        res = pose.process(rgb)

        # Prepare a VIEW frame (mirrored only for display)
        view = cv2.flip(frame_bgr, 1) if DISPLAY_MIRROR else frame_bgr.copy()

        if res.pose_landmarks:
            # RIGHT arm
            try:
                rS, rE, rW = get_arm_landmarks_xy(res.pose_landmarks.landmark, w, h, "right")
                r_angle = angle_between(rS, rE, rW)
                right.update(r_angle, (int(rE[0]), int(rE[1])))

                # draw short segment on VIEW (mirror coords if needed)
                rpts = [tuple(map(int, rS)), tuple(map(int, rE)), tuple(map(int, rW))]
                if DISPLAY_MIRROR: rpts = [mirror_xy(p, w) for p in rpts]
                cv2.circle(view, rpts[0], 6, (0, 255, 255), -1)
                cv2.circle(view, rpts[1], 8, (0, 165, 255), -1)
                cv2.circle(view, rpts[2], 6, (0, 255, 255), -1)
                cv2.line(view, rpts[0], rpts[1], (0, 200, 0), 3)
                cv2.line(view, rpts[1], rpts[2], (0, 200, 0), 3)
            except Exception:
                pass

            # LEFT arm
            try:
                lS, lE, lW = get_arm_landmarks_xy(res.pose_landmarks.landmark, w, h, "left")
                l_angle = angle_between(lS, lE, lW)
                left.update(l_angle, (int(lE[0]), int(lE[1])))

                lpts = [tuple(map(int, lS)), tuple(map(int, lE)), tuple(map(int, lW))]
                if DISPLAY_MIRROR: lpts = [mirror_xy(p, w) for p in lpts]
                cv2.circle(view, lpts[0], 6, (0, 255, 255), -1)
                cv2.circle(view, lpts[1], 8, (0, 165, 255), -1)
                cv2.circle(view, lpts[2], 6, (0, 255, 255), -1)
                cv2.line(view, lpts[0], lpts[1], (0, 200, 0), 3)
                cv2.line(view, lpts[1], lpts[2], (0, 200, 0), 3)
            except Exception:
                pass

        # FPS
        t = time.time()
        fps = 1.0 / max(t - t_prev, 1e-6); t_prev = t

        # Angle labels near elbows on VIEW
        if right.angle_vis_deg is not None and right.elbow_xy is not None:
            rxy = mirror_xy(right.elbow_xy, w) if DISPLAY_MIRROR else right.elbow_xy
            cv2.putText(view, f"R:{int(right.angle_vis_deg)}°", (rxy[0]+10, rxy[1]-10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255,255,255), 2)
        if left.angle_vis_deg is not None and left.elbow_xy is not None:
            lxy = mirror_xy(left.elbow_xy, w) if DISPLAY_MIRROR else left.elbow_xy
            cv2.putText(view, f"L:{int(left.angle_vis_deg)}°", (lxy[0]+10, lxy[1]-10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255,255,255), 2)

        # HUD (top-left is fine either way)
        cv2.putText(view,
                    f"Left Reps: {left.reps} (state:{left.state})   Right Reps: {right.reps} (state:{right.state})",
                    (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (255,255,255), 2)
        cv2.putText(view, f"Up<{ANGLE_UP}°, Down>{ANGLE_DOWN}°   FPS:{fps:.1f}",
                    (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (200,200,200), 2)

        cv2.imshow("Dual-Arm Curl Detector (Mirrored View Only)", view)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    pose.close()
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# Press 'q' to quit.
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.160929024
# y: 1.01446092
# z: -1.57490265
# visibility: 0.944450855
# , E = x: 0.0610180497
# y: 1.30068588
# z: -1.68949533
# visibility: 0.398808122
# , W = x: 0.241609842
# y: 1.06212926
# z: -1.79551065
# visibility: 0.156863496
#
# S.x * w = 0.16092902421951294 * 640 = 102.99457550048828
#
# S.y * h = 1.0144609212875366 * 480 = 486.9412422180176
#
# shoulder = [102.9945755  486.94124222], elbow = [ 39.05155182 624.32922363], wrist = [154.63029861 509.82204437]
# shoulder - elbow = [  63.94302368 -137.38798141], elbow - wrist = [ 115.5787468  -114.50717926]
# hypotenuse (shoulder - elbow) = 151.539327297615, hypotenuse (elbow - wrist) = 162.69708299858308
# cosang = 0.9378364896924541
# theta = 0.35445297340958287
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.710974216
# y: 1.03657389
# z: -1.54313684
# visibility: 0.955373764
# , E = x: 0.821779728
# y: 1.28983104
# z: -1.43394947
# visibility: 0.367357343
# , W = x: 0.632277727
# y: 1.06171107
# z: -1.18243873
# visibility: 0.0876827762
#
# S.x * w = 0.7109742164611816 * 640 = 455.02349853515625
#
# S.y * h = 1.036573886871338 * 480 = 497.5554656982422
#
# shoulder = [455.02349854 497.5554657 ], elbow = [525.93902588 619.1189003 ], wrist = [404.65774536 509.621315  ]
# shoulder - elbow = [ -70.91552734 -121.5634346 ], elbow - wrist = [-121.28128052 -109.4975853 ]
# hypotenuse (shoulder - elbow) = 140.73620946013563, hypotenuse (elbow - wrist) = 163.39788919396844
# cosang = 0.9528452310941455
# theta = 0.3083183296734469
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.153468698
# y: 1.01883757
# z: -1.80080056
# visibility: 0.943349183
# , E = x: 0.0476564392
# y: 1.39078164
# z: -1.67027724
# visibility: 0.396717668
# , W = x: 0.242270589
# y: 1.10742426
# z: -1.44054329
# visibility: 0.147843719
#
# S.x * w = 0.15346869826316833 * 640 = 98.21996688842773
#
# S.y * h = 1.018837571144104 * 480 = 489.0420341491699
#
# shoulder = [ 98.21996689 489.04203415], elbow = [ 30.50012112 667.57518768], wrist = [155.05317688 531.56364441]
# shoulder - elbow = [  67.71984577 -178.53315353], elbow - wrist = [ 124.55305576 -136.01154327]
# hypotenuse (shoulder - elbow) = 190.94518696721755, hypotenuse (elbow - wrist) = 184.42506230825956
# cosang = 0.9290703107568862
# theta = 0.3789047996948318
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.720277429
# y: 1.03029752
# z: -1.65732
# visibility: 0.950472772
# , E = x: 0.836172
# y: 1.29493904
# z: -1.18198967
# visibility: 0.347955316
# , W = x: 0.664874434
# y: 1.14893174
# z: -0.640250266
# visibility: 0.0817266703
#
# S.x * w = 0.7202774286270142 * 640 = 460.97755432128906
#
# S.y * h = 1.0302975177764893 * 480 = 494.54280853271484
#
# shoulder = [460.97755432 494.54280853], elbow = [535.15007019 621.57073975], wrist = [425.51963806 551.48723602]
# shoulder - elbow = [ -74.17251587 -127.02793121], elbow - wrist = [-109.63043213  -70.08350372]
# hypotenuse (shoulder - elbow) = 147.09744192762426, hypotenuse (elbow - wrist) = 130.11736680968102
# cosang = 0.8899784820436422
# theta = 0.4734983476848728
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.152188033
# y: 1.0329088
# z: -1.75774348
# visibility: 0.942471206
# , E = x: 0.0386174433
# y: 1.40275347
# z: -1.59260321
# visibility: 0.398883492
# , W = x: 0.239199713
# y: 1.10668802
# z: -1.3650285
# visibility: 0.139249384
#
# S.x * w = 0.1521880328655243 * 640 = 97.40034103393555
#
# S.y * h = 1.0329087972640991 * 480 = 495.7962226867676
#
# shoulder = [ 97.40034103 495.79622269], elbow = [ 24.71516371 673.32166672], wrist = [153.08781624 531.21025085]
# shoulder - elbow = [  72.68517733 -177.52544403], elbow - wrist = [ 128.37265253 -142.11141586]
# hypotenuse (shoulder - elbow) = 191.82913825875667, hypotenuse (elbow - wrist) = 191.50768245735577
# cosang = 0.9407249617696384
# theta = 0.3460348622718625
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.734412789
# y: 1.02497673
# z: -1.69328594
# visibility: 0.946005225
# , E = x: 0.865188241
# y: 1.29481375
# z: -1.24903631
# visibility: 0.335457087
# , W = x: 0.690376878
# y: 1.15175653
# z: -0.765447497
# visibility: 0.0769208297
#
# S.x * w = 0.7344127893447876 * 640 = 470.02418518066406
#
# S.y * h = 1.0249767303466797 * 480 = 491.98883056640625
#
# shoulder = [470.02418518 491.98883057], elbow = [553.72047424 621.51060104], wrist = [441.84120178 552.84313202]
# shoulder - elbow = [ -83.69628906 -129.52177048], elbow - wrist = [-111.87927246  -68.66746902]
# hypotenuse (shoulder - elbow) = 154.21075783968783, hypotenuse (elbow - wrist) = 131.27144743342518
# cosang = 0.9019112157720671
# theta = 0.4466221387211776
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.158911511
# y: 1.03674829
# z: -1.56793892
# visibility: 0.945744634
# , E = x: 0.035696771
# y: 1.38879573
# z: -1.74226665
# visibility: 0.413414121
# , W = x: 0.246552706
# y: 1.0614121
# z: -1.84526801
# visibility: 0.141989
#
# S.x * w = 0.15891151130199432 * 640 = 101.70336723327637
#
# S.y * h = 1.0367482900619507 * 480 = 497.6391792297363
#
# shoulder = [101.70336723 497.63917923], elbow = [ 22.84593344 666.62195206], wrist = [157.79373169 509.47780609]
# shoulder - elbow = [  78.8574338  -168.98277283], elbow - wrist = [ 134.94779825 -157.14414597]
# hypotenuse (shoulder - elbow) = 186.47700228435818, hypotenuse (elbow - wrist) = 207.13568226764806
# cosang = 0.9629848032710324
# theta = 0.27293161068536254
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.734541118
# y: 1.01630151
# z: -1.43959808
# visibility: 0.947750449
# , E = x: 0.862259746
# y: 1.29731977
# z: -1.15038049
# visibility: 0.333663702
# , W = x: 0.68345207
# y: 1.14603198
# z: -0.731407285
# visibility: 0.0768172517
#
# S.x * w = 0.734541118144989 * 640 = 470.10631561279297
#
# S.y * h = 1.0163015127182007 * 480 = 487.8247261047363
#
# shoulder = [470.10631561 487.8247261 ], elbow = [551.84623718 622.71348953], wrist = [437.40932465 550.09534836]
# shoulder - elbow = [ -81.73992157 -134.88876343], elbow - wrist = [-114.43691254  -72.61814117]
# hypotenuse (shoulder - elbow) = 157.7225198900232, hypotenuse (elbow - wrist) = 135.53302690207238
# cosang = 0.895812528034139
# theta = 0.4605402404885797
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.156477362
# y: 1.03656328
# z: -1.57599425
# visibility: 0.949985147
# , E = x: 0.048785679
# y: 1.36711872
# z: -1.43489373
# visibility: 0.42538172
# , W = x: 0.259843111
# y: 1.04098713
# z: -0.885046661
# visibility: 0.136303
#
# S.x * w = 0.15647736191749573 * 640 = 100.14551162719727
#
# S.y * h = 1.0365632772445679 * 480 = 497.5503730773926
#
# shoulder = [100.14551163 497.55037308], elbow = [ 31.22283459 656.2169838 ], wrist = [166.29959106 499.67382431]
# shoulder - elbow = [  68.92267704 -158.66661072], elbow - wrist = [ 135.07675648 -156.54315948]
# hypotenuse (shoulder - elbow) = 172.9896782195377, hypotenuse (elbow - wrist) = 206.764336688128
# cosang = 0.9547062315278567
# theta = 0.3021254055164905
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.721811414
# y: 1.01146173
# z: -1.41546285
# visibility: 0.949994445
# , E = x: 0.857544899
# y: 1.2326082
# z: -0.91609621
# visibility: 0.334061831
# , W = x: 0.676402867
# y: 1.0857991
# z: -0.255513757
# visibility: 0.0749473
#
# S.x * w = 0.7218114137649536 * 640 = 461.9593048095703
#
# S.y * h = 1.0114617347717285 * 480 = 485.5016326904297
#
# shoulder = [461.95930481 485.50163269], elbow = [548.82873535 591.65193558], wrist = [432.89783478 521.18356705]
# shoulder - elbow = [ -86.86943054 -106.15030289], elbow - wrist = [-115.93090057  -70.46836853]
# hypotenuse (shoulder - elbow) = 137.16480878281888, hypotenuse (elbow - wrist) = 135.66784686825383
# cosang = 0.9431580107186378
# theta = 0.33878844724566104
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.155169517
# y: 1.03627729
# z: -1.66011679
# visibility: 0.945623755
# , E = x: 0.0446400717
# y: 1.36597788
# z: -1.41131139
# visibility: 0.432910383
# , W = x: 0.258565068
# y: 1.03750694
# z: -0.933179498
# visibility: 0.131214023
#
# S.x * w = 0.1551695168018341 * 640 = 99.30849075317383
#
# S.y * h = 1.0362772941589355 * 480 = 497.41310119628906
#
# shoulder = [ 99.30849075 497.4131012 ], elbow = [ 28.56964588 655.669384  ], wrist = [165.48164368 498.00333023]
# shoulder - elbow = [  70.73884487 -158.25628281], elbow - wrist = [ 136.9119978  -157.66605377]
# hypotenuse (shoulder - elbow) = 173.34657546349794, hypotenuse (elbow - wrist) = 208.8144622779986
# cosang = 0.9568853758423996
# theta = 0.29471358323287256
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.718375087
# y: 1.09445059
# z: -1.45258939
# visibility: 0.94116509
# , E = x: 0.842864692
# y: 1.3192544
# z: -1.00503671
# visibility: 0.32449168
# , W = x: 0.675061107
# y: 1.13484991
# z: -0.524981439
# visibility: 0.0737286434
#
# S.x * w = 0.7183750867843628 * 640 = 459.7600555419922
#
# S.y * h = 1.09445059299469 * 480 = 525.3362846374512
#
# shoulder = [459.76005554 525.33628464], elbow = [539.43340302 633.24211121], wrist = [432.03910828 544.72795486]
# shoulder - elbow = [ -79.67334747 -107.90582657], elbow - wrist = [-107.39429474  -88.51415634]
# hypotenuse (shoulder - elbow) = 134.13243346675188, hypotenuse (elbow - wrist) = 139.1700054540415
# cosang = 0.9700246963610732
# theta = 0.24546390966311044
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.154961482
# y: 1.03577566
# z: -1.64300501
# visibility: 0.947542608
# , E = x: 0.0365831889
# y: 1.36449659
# z: -1.56939089
# visibility: 0.450586438
# , W = x: 0.257866502
# y: 1.01845622
# z: -1.21806788
# visibility: 0.131000042
#
# S.x * w = 0.1549614816904068 * 640 = 99.17534828186035
#
# S.y * h = 1.0357756614685059 * 480 = 497.1723175048828
#
# shoulder = [ 99.17534828 497.1723175 ], elbow = [ 23.41324091 654.95836258], wrist = [165.03456116 488.8589859 ]
# shoulder - elbow = [  75.76210737 -157.78604507], elbow - wrist = [ 141.62132025 -166.09937668]
# hypotenuse (shoulder - elbow) = 175.0323768256335, hypotenuse (elbow - wrist) = 218.27872385101637
# cosang = 0.9668074223152437
# theta = 0.25837122554193703
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.718828559
# y: 1.0604161
# z: -1.45156467
# visibility: 0.939206958
# , E = x: 0.843515575
# y: 1.29268491
# z: -1.01306105
# visibility: 0.313498825
# , W = x: 0.673041403
# y: 1.129053
# z: -0.467856795
# visibility: 0.0702921
#
# S.x * w = 0.718828558921814 * 640 = 460.05027770996094
#
# S.y * h = 1.0604161024093628 * 480 = 508.99972915649414
#
# shoulder = [460.05027771 508.99972916], elbow = [539.84996796 620.48875809], wrist = [430.74649811 541.94543839]
# shoulder - elbow = [ -79.79969025 -111.48902893], elbow - wrist = [-109.10346985  -78.5433197 ]
# hypotenuse (shoulder - elbow) = 137.10504782135118, hypotenuse (elbow - wrist) = 134.43444575529784
# cosang = 0.9474545122276852
# theta = 0.32561393739943945
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.153475434
# y: 1.02460694
# z: -1.73543227
# visibility: 0.942976654
# , E = x: 0.0365270227
# y: 1.38531244
# z: -1.39236867
# visibility: 0.451791614
# , W = x: 0.247119188
# y: 1.05366206
# z: -0.895418823
# visibility: 0.126296937
#
# S.x * w = 0.15347543358802795 * 640 = 98.22427749633789
#
# S.y * h = 1.0246069431304932 * 480 = 491.8113327026367
#
# shoulder = [ 98.2242775 491.8113327], elbow = [ 23.37729454 664.94997025], wrist = [158.15628052 505.75778961]
# shoulder - elbow = [  74.84698296 -173.13863754], elbow - wrist = [ 134.77898598 -159.19218063]
# hypotenuse (shoulder - elbow) = 188.62412006826995, hypotenuse (elbow - wrist) = 208.58457622765363
# cosang = 0.9569448738017376
# theta = 0.294508677701806
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.721570373
# y: 1.1011461
# z: -1.59757912
# visibility: 0.931742191
# , E = x: 0.844126582
# y: 1.31502378
# z: -1.07764864
# visibility: 0.300231069
# , W = x: 0.680202425
# y: 1.17689133
# z: -0.597622931
# visibility: 0.0674873
#
# S.x * w = 0.7215703725814819 * 640 = 461.80503845214844
#
# S.y * h = 1.1011461019515991 * 480 = 528.5501289367676
#
# shoulder = [461.80503845 528.55012894], elbow = [540.24101257 631.21141434], wrist = [435.3295517  564.90783691]
# shoulder - elbow = [ -78.43597412 -102.6612854 ], elbow - wrist = [-104.91146088  -66.30357742]
# hypotenuse (shoulder - elbow) = 129.1957489972842, hypotenuse (elbow - wrist) = 124.10712713142868
# cosang = 0.9377283847795347
# theta = 0.35476431451741736
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.160280138
# y: 1.02460694
# z: -1.67085207
# visibility: 0.926872253
# , E = x: 0.0480566546
# y: 1.37955248
# z: -1.24538994
# visibility: 0.449822456
# , W = x: 0.252459913
# y: 1.03151679
# z: -0.740924835
# visibility: 0.121356033
#
# S.x * w = 0.16028013825416565 * 640 = 102.57928848266602
#
# S.y * h = 1.0246069431304932 * 480 = 491.8113327026367
#
# shoulder = [102.57928848 491.8113327 ], elbow = [ 30.75625896 662.18519211], wrist = [161.57434464 495.12805939]
# shoulder - elbow = [  71.82302952 -170.37385941], elbow - wrist = [ 130.81808567 -167.05713272]
# hypotenuse (shoulder - elbow) = 184.89402246041044, hypotenuse (elbow - wrist) = 212.18260328234874
# cosang = 0.9649928623335715
# theta = 0.2653801652784429
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.721874952
# y: 1.07597232
# z: -1.5937258
# visibility: 0.913966537
# , E = x: 0.843812764
# y: 1.27093744
# z: -1.10459244
# visibility: 0.290286779
# , W = x: 0.67203629
# y: 1.14799631
# z: -0.632879555
# visibility: 0.0647683814
#
# S.x * w = 0.7218749523162842 * 640 = 461.9999694824219
#
# S.y * h = 1.075972318649292 * 480 = 516.4667129516602
#
# shoulder = [461.99996948 516.46671295], elbow = [540.04016876 610.04997253], wrist = [430.10322571 551.03822708]
# shoulder - elbow = [-78.04019928 -93.58325958], elbow - wrist = [-109.93694305  -59.01174545]
# hypotenuse (shoulder - elbow) = 121.85277666165375, hypotenuse (elbow - wrist) = 124.77386566101622
# cosang = 0.9275173306314259
# theta = 0.38308124904348784
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.160956532
# y: 1.02407432
# z: -1.7553699
# visibility: 0.919317842
# , E = x: 0.0478108115
# y: 1.37678897
# z: -1.33812249
# visibility: 0.44149977
# , W = x: 0.234870762
# y: 1.03397679
# z: -0.886683762
# visibility: 0.114488356
#
# S.x * w = 0.16095653176307678 * 640 = 103.01218032836914
#
# S.y * h = 1.0240743160247803 * 480 = 491.55567169189453
#
# shoulder = [103.01218033 491.55567169], elbow = [ 30.59891939 660.85870743], wrist = [150.31728745 496.30886078]
# shoulder - elbow = [  72.41326094 -169.30303574], elbow - wrist = [ 119.71836805 -164.54984665]
# hypotenuse (shoulder - elbow) = 184.13907318282148, hypotenuse (elbow - wrist) = 203.49235780665873
# cosang = 0.9748362510450111
# theta = 0.22481102564040537
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.729375482
# y: 1.06625795
# z: -1.67836571
# visibility: 0.899444
# , E = x: 0.860734165
# y: 1.25165737
# z: -1.11668599
# visibility: 0.274967909
# , W = x: 0.671856761
# y: 1.14750886
# z: -0.608382761
# visibility: 0.0600831285
#
# S.x * w = 0.7293754816055298 * 640 = 466.80030822753906
#
# S.y * h = 1.0662579536437988 * 480 = 511.80381774902344
#
# shoulder = [466.80030823 511.80381775], elbow = [550.86986542 600.79553604], wrist = [429.98832703 550.80425262]
# shoulder - elbow = [-84.06955719 -88.99171829], elbow - wrist = [-120.88153839  -49.99128342]
# hypotenuse (shoulder - elbow) = 122.42228707701071, hypotenuse (elbow - wrist) = 130.8108357288189
# cosang = 0.9123966588975191
# theta = 0.42169455073965834
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.154263526
# y: 1.02397335
# z: -1.81941354
# visibility: 0.921232
# , E = x: 0.0557493456
# y: 1.31337273
# z: -1.3615216
# visibility: 0.450273573
# , W = x: 0.234696388
# y: 1.02429652
# z: -1.01169157
# visibility: 0.110916674
#
# S.x * w = 0.15426352620124817 * 640 = 98.72865676879883
#
# S.y * h = 1.0239733457565308 * 480 = 491.50720596313477
#
# shoulder = [ 98.72865677 491.50720596], elbow = [ 35.67958117 630.41891098], wrist = [150.20568848 491.66233063]
# shoulder - elbow = [  63.0490756  -138.91170502], elbow - wrist = [ 114.52610731 -138.75658035]
# hypotenuse (shoulder - elbow) = 152.55047600142052, hypotenuse (elbow - wrist) = 179.9155853467519
# cosang = 0.9653675356268476
# theta = 0.26394784559975687
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.723514915
# y: 1.03975344
# z: -1.56527841
# visibility: 0.899910867
# , E = x: 0.833582222
# y: 1.13227212
# z: -0.879251361
# visibility: 0.266334
# , W = x: 0.655660331
# y: 1.05856204
# z: -0.445070893
# visibility: 0.0574602745
#
# S.x * w = 0.7235149145126343 * 640 = 463.04954528808594
#
# S.y * h = 1.0397534370422363 * 480 = 499.08164978027344
#
# shoulder = [463.04954529 499.08164978], elbow = [533.49262238 543.49061966], wrist = [419.622612   508.10977936]
# shoulder - elbow = [-70.44307709 -44.40896988], elbow - wrist = [-113.87001038  -35.3808403 ]
# hypotenuse (shoulder - elbow) = 83.27294708928257, hypotenuse (elbow - wrist) = 119.2400231711275
# cosang = 0.9660719440778076
# theta = 0.26123423598366446
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.150941238
# y: 1.03249824
# z: -1.92005193
# visibility: 0.915473938
# , E = x: 0.0510713942
# y: 1.31426013
# z: -1.39530957
# visibility: 0.450445384
# , W = x: 0.228103727
# y: 1.02581048
# z: -0.900562644
# visibility: 0.105525248
#
# S.x * w = 0.15094123780727386 * 640 = 96.60239219665527
#
# S.y * h = 1.0324982404708862 * 480 = 495.5991554260254
#
# shoulder = [ 96.6023922  495.59915543], elbow = [ 32.68569231 630.84486008], wrist = [145.98638535 492.38903046]
# shoulder - elbow = [  63.91669989 -135.24570465], elbow - wrist = [ 113.30069304 -138.45582962]
# hypotenuse (shoulder - elbow) = 149.5885863087913, hypotenuse (elbow - wrist) = 178.90518103643734
# cosang = 0.9703009737852558
# theta = 0.24432440341238768
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.726055801
# y: 1.03857267
# z: -1.77449358
# visibility: 0.885864
# , E = x: 0.833564579
# y: 1.16025698
# z: -1.12879705
# visibility: 0.260193706
# , W = x: 0.639338672
# y: 1.03417885
# z: -0.520113409
# visibility: 0.0546179
#
# S.x * w = 0.7260558009147644 * 640 = 464.6757125854492
#
# S.y * h = 1.0385726690292358 * 480 = 498.5148811340332
#
# shoulder = [464.67571259 498.51488113], elbow = [533.48133087 556.92335129], wrist = [409.17675018 496.40584946]
# shoulder - elbow = [-68.80561829 -58.40847015], elbow - wrist = [-124.30458069  -60.51750183]
# hypotenuse (shoulder - elbow) = 90.25387800671193, hypotenuse (elbow - wrist) = 138.25337902118255
# cosang = 0.9687194750798515
# theta = 0.2507786976857781
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.151184231
# y: 1.03333902
# z: -1.94433177
# visibility: 0.914880455
# , E = x: 0.0520720668
# y: 1.3176446
# z: -1.47106743
# visibility: 0.453808904
# , W = x: 0.228493169
# y: 1.02675343
# z: -0.977159202
# visibility: 0.102105319
#
# S.x * w = 0.15118423104286194 * 640 = 96.75790786743164
#
# S.y * h = 1.033339023590088 * 480 = 496.0027313232422
#
# shoulder = [ 96.75790787 496.00273132], elbow = [ 33.32612276 632.46940613], wrist = [146.23562813 492.84164429]
# shoulder - elbow = [  63.43178511 -136.4666748 ], elbow - wrist = [ 112.90950537 -139.62776184]
# hypotenuse (shoulder - elbow) = 150.48835402473992, hypotenuse (elbow - wrist) = 179.5674477252261
# cosang = 0.9701651380666056
# theta = 0.24488530715549767
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.727146804
# y: 1.03484476
# z: -1.77315366
# visibility: 0.879754
# , E = x: 0.844156265
# y: 1.11810803
# z: -1.1354686
# visibility: 0.255426913
# , W = x: 0.624612689
# y: 1.005229
# z: -0.526392937
# visibility: 0.0518405512
#
# S.x * w = 0.7271468043327332 * 640 = 465.3739547729492
#
# S.y * h = 1.0348447561264038 * 480 = 496.7254829406738
#
# shoulder = [465.37395477 496.72548294], elbow = [540.26000977 536.69185638], wrist = [399.75212097 482.50991821]
# shoulder - elbow = [-74.88605499 -39.96637344], elbow - wrist = [-140.50788879  -54.18193817]
# hypotenuse (shoulder - elbow) = 84.88363941477361, hypotenuse (elbow - wrist) = 150.5926599816589
# cosang = 0.9925434497252027
# theta = 0.12219521623551352
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.153337345
# y: 1.02352357
# z: -1.87766969
# visibility: 0.907110274
# , E = x: 0.0664183348
# y: 1.31979501
# z: -1.43334782
# visibility: 0.450675964
# , W = x: 0.25130254
# y: 1.03023
# z: -0.924595952
# visibility: 0.100213945
#
# S.x * w = 0.15333734452724457 * 640 = 98.13590049743652
#
# S.y * h = 1.0235235691070557 * 480 = 491.2913131713867
#
# shoulder = [ 98.1359005  491.29131317], elbow = [ 42.5077343  633.50160599], wrist = [160.83362579 494.51042175]
# shoulder - elbow = [  55.6281662  -142.21029282], elbow - wrist = [ 118.32589149 -138.99118423]
# hypotenuse (shoulder - elbow) = 152.7031769824918, hypotenuse (elbow - wrist) = 182.5364782628945
# cosang = 0.9452652563366337
# theta = 0.3323897644773384
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.727163136
# y: 1.0336113
# z: -1.79791486
# visibility: 0.874534369
# , E = x: 0.839157
# y: 1.13806975
# z: -1.24854231
# visibility: 0.255550683
# , W = x: 0.616640687
# y: 1.01078212
# z: -0.716575921
# visibility: 0.0517723709
#
# S.x * w = 0.7271631360054016 * 640 = 465.38440704345703
#
# S.y * h = 1.0336112976074219 * 480 = 496.1334228515625
#
# shoulder = [465.38440704 496.13342285], elbow = [537.06047058 546.27347946], wrist = [394.65003967 485.17541885]
# shoulder - elbow = [-71.67606354 -50.14005661], elbow - wrist = [-142.41043091  -61.09806061]
# hypotenuse (shoulder - elbow) = 87.47275783271022, hypotenuse (elbow - wrist) = 154.9635565047706
# cosang = 0.9790329428640749
# theta = 0.20513770577053905
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.153110489
# y: 1.02434516
# z: -1.67344499
# visibility: 0.903822
# , E = x: 0.0638506114
# y: 1.36018932
# z: -1.3545264
# visibility: 0.446501702
# , W = x: 0.247955248
# y: 1.05631244
# z: -0.773053646
# visibility: 0.0959743485
#
# S.x * w = 0.15311048924922943 * 640 = 97.99071311950684
#
# S.y * h = 1.0243451595306396 * 480 = 491.68567657470703
#
# shoulder = [ 97.99071312 491.68567657], elbow = [ 40.86439133 652.89087296], wrist = [158.69135857 507.02997208]
# shoulder - elbow = [  57.12632179 -161.20519638], elbow - wrist = [ 117.82696724 -145.86090088]
# hypotenuse (shoulder - elbow) = 171.02786903041638, hypotenuse (elbow - wrist) = 187.50625754301146
# cosang = 0.9431148191489653
# theta = 0.3389183834665152
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.727593541
# y: 1.03615928
# z: -1.52074778
# visibility: 0.858046055
# , E = x: 0.841504395
# y: 1.21247232
# z: -0.98714751
# visibility: 0.244856626
# , W = x: 0.619016051
# y: 1.05531418
# z: -0.232711166
# visibility: 0.0484920591
#
# S.x * w = 0.7275935411453247 * 640 = 465.6598663330078
#
# S.y * h = 1.0361592769622803 * 480 = 497.35645294189453
#
# shoulder = [465.65986633 497.35645294], elbow = [538.56281281 581.98671341], wrist = [396.17027283 506.55080795]
# shoulder - elbow = [-72.90294647 -84.63026047], elbow - wrist = [-142.39253998  -75.43590546]
# hypotenuse (shoulder - elbow) = 111.70103219469219, hypotenuse (elbow - wrist) = 161.14034652024742
# cosang = 0.9314123150399476
# theta = 0.3725221988881019
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.145858467
# y: 1.02726269
# z: -1.69392991
# visibility: 0.907430947
# , E = x: 0.0597153716
# y: 1.3496381
# z: -1.374704
# visibility: 0.450846493
# , W = x: 0.220299318
# y: 1.05802965
# z: -0.874677181
# visibility: 0.0938071162
#
# S.x * w = 0.14585846662521362 * 640 = 93.34941864013672
#
# S.y * h = 1.0272626876831055 * 480 = 493.0860900878906
#
# shoulder = [ 93.34941864 493.08609009], elbow = [ 38.21783781 647.82629013], wrist = [140.9915638  507.85423279]
# shoulder - elbow = [  55.13158083 -154.74020004], elbow - wrist = [ 102.77372599 -139.97205734]
# hypotenuse (shoulder - elbow) = 164.268136646523, hypotenuse (elbow - wrist) = 173.65084391766587
# cosang = 0.9579349419973728
# theta = 0.2910784191730486
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.724582613
# y: 1.03668869
# z: -1.4772948
# visibility: 0.857586384
# , E = x: 0.839375854
# y: 1.19802988
# z: -0.840578556
# visibility: 0.241244629
# , W = x: 0.620672822
# y: 1.05253232
# z: -0.333931327
# visibility: 0.0470822193
#
# S.x * w = 0.7245826125144958 * 640 = 463.73287200927734
#
# S.y * h = 1.0366886854171753 * 480 = 497.61056900024414
#
# shoulder = [463.73287201 497.610569  ], elbow = [537.20054626 575.05434036], wrist = [397.23060608 505.21551132]
# shoulder - elbow = [-73.46767426 -77.44377136], elbow - wrist = [-139.96994019  -69.83882904]
# hypotenuse (shoulder - elbow) = 106.74753807674063, hypotenuse (elbow - wrist) = 156.42584888830265
# cosang = 0.9397399984466347
# theta = 0.34892730101532726
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.144260436
# y: 1.02945673
# z: -1.92884326
# visibility: 0.903904319
# , E = x: 0.0600638203
# y: 1.36429513
# z: -1.3895061
# visibility: 0.443419963
# , W = x: 0.215871125
# y: 1.06566823
# z: -0.810044646
# visibility: 0.0902629644
#
# S.x * w = 0.144260436296463 * 640 = 92.32667922973633
#
# S.y * h = 1.0294567346572876 * 480 = 494.13923263549805
#
# shoulder = [ 92.32667923 494.13923264], elbow = [ 38.44084501 654.86166   ], wrist = [138.15752029 511.52074814]
# shoulder - elbow = [  53.88583422 -160.72242737], elbow - wrist = [  99.71667528 -143.34091187]
# hypotenuse (shoulder - elbow) = 169.5151373529066, hypotenuse (elbow - wrist) = 174.61395232641118
# cosang = 0.9598545844171507
# theta = 0.28431298905101315
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.738847852
# y: 1.03668582
# z: -1.77830827
# visibility: 0.853170931
# , E = x: 0.867248237
# y: 1.17375314
# z: -1.0547576
# visibility: 0.236203656
# , W = x: 0.632033
# y: 1.04937088
# z: -0.394685924
# visibility: 0.0450278968
#
# S.x * w = 0.7388478517532349 * 640 = 472.8626251220703
#
# S.y * h = 1.036685824394226 * 480 = 497.6091957092285
#
# shoulder = [472.86262512 497.60919571], elbow = [555.03887177 563.40150833], wrist = [404.50111389 503.69802475]
# shoulder - elbow = [-82.17624664 -65.79231262], elbow - wrist = [-150.53775787  -59.70348358]
# hypotenuse (shoulder - elbow) = 105.26900737922674, hypotenuse (elbow - wrist) = 161.94481313275077
# cosang = 0.9560580906425201
# theta = 0.29754848236535525
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.144343823
# y: 1.02821398
# z: -1.91809332
# visibility: 0.905232131
# , E = x: 0.0561274663
# y: 1.3583926
# z: -1.35562551
# visibility: 0.438491106
# , W = x: 0.197581157
# y: 1.0675931
# z: -0.867432773
# visibility: 0.087832205
#
# S.x * w = 0.14434382319450378 * 640 = 92.38004684448242
#
# S.y * h = 1.0282139778137207 * 480 = 493.54270935058594
#
# shoulder = [ 92.38004684 493.54270935], elbow = [ 35.92157841 652.0284462 ], wrist = [126.45194054 512.44468689]
# shoulder - elbow = [  56.45846844 -158.48573685], elbow - wrist = [  90.53036213 -139.58375931]
# hypotenuse (shoulder - elbow) = 168.24175297930935, hypotenuse (elbow - wrist) = 166.37118841039918
# cosang = 0.9729430460393295
# theta = 0.23315168952957233
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.738715112
# y: 1.03660262
# z: -1.6799593
# visibility: 0.849707127
# , E = x: 0.865347862
# y: 1.1717608
# z: -0.972388744
# visibility: 0.229995504
# , W = x: 0.632556498
# y: 1.05313158
# z: -0.446026
# visibility: 0.0431118421
#
# S.x * w = 0.7387151122093201 * 640 = 472.77767181396484
#
# S.y * h = 1.0366026163101196 * 480 = 497.5692558288574
#
# shoulder = [472.77767181 497.56925583], elbow = [553.82263184 562.4451828 ], wrist = [404.83615875 505.50315857]
# shoulder - elbow = [-81.04496002 -64.87592697], elbow - wrist = [-148.98647308  -56.94202423]
# hypotenuse (shoulder - elbow) = 103.81315642750897, hypotenuse (elbow - wrist) = 159.4972203161176
# cosang = 0.9523405715121432
# theta = 0.3099770474379407
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.143559873
# y: 1.02484214
# z: -1.87549901
# visibility: 0.898335338
# , E = x: 0.0560395941
# y: 1.35902619
# z: -1.34421921
# visibility: 0.424503326
# , W = x: 0.198376775
# y: 1.06599641
# z: -0.74428916
# visibility: 0.0835155472
#
# S.x * w = 0.14355987310409546 * 640 = 91.8783187866211
#
# S.y * h = 1.0248421430587769 * 480 = 491.9242286682129
#
# shoulder = [ 91.87831879 491.92422867], elbow = [ 35.86534023 652.33257294], wrist = [126.96113586 511.67827606]
# shoulder - elbow = [  56.01297855 -160.40834427], elbow - wrist = [  91.09579563 -140.65429688]
# hypotenuse (shoulder - elbow) = 169.90671170062984, hypotenuse (elbow - wrist) = 167.577072460619
# cosang = 0.9716287475611962
# theta = 0.23877366445815545
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.737609148
# y: 1.03663683
# z: -1.70898783
# visibility: 0.839090407
# , E = x: 0.861099362
# y: 1.20004511
# z: -1.02282131
# visibility: 0.218852356
# , W = x: 0.632612824
# y: 1.06324971
# z: -0.467306197
# visibility: 0.0406318568
#
# S.x * w = 0.7376091480255127 * 640 = 472.0698547363281
#
# S.y * h = 1.0366368293762207 * 480 = 497.58567810058594
#
# shoulder = [472.06985474 497.5856781 ], elbow = [551.10359192 576.02165222], wrist = [404.87220764 510.35985947]
# shoulder - elbow = [-79.03373718 -78.43597412], elbow - wrist = [-146.23138428  -65.66179276]
# hypotenuse (shoulder - elbow) = 111.3487029632715, hypotenuse (elbow - wrist) = 160.29687700854112
# cosang = 0.9360524674808549
# theta = 0.3595579146901826
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.143176943
# y: 1.03425086
# z: -1.80848634
# visibility: 0.902302802
# , E = x: 0.0404825
# y: 1.36103809
# z: -1.48366141
# visibility: 0.427321404
# , W = x: 0.19139789
# y: 1.07263458
# z: -1.20754838
# visibility: 0.0822284818
#
# S.x * w = 0.14317694306373596 * 640 = 91.63324356079102
#
# S.y * h = 1.0342508554458618 * 480 = 496.4404106140137
#
# shoulder = [ 91.63324356 496.44041061], elbow = [ 25.90879917 653.29828262], wrist = [122.49464989 514.86459732]
# shoulder - elbow = [  65.72444439 -156.85787201], elbow - wrist = [  96.58585072 -138.4336853 ]
# hypotenuse (shoulder - elbow) = 170.07085172059357, hypotenuse (elbow - wrist) = 168.7978429611463
# cosang = 0.9775276088932203
# theta = 0.21240088148830155
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.737383962
# y: 1.03605223
# z: -1.57481408
# visibility: 0.837428093
# , E = x: 0.860898376
# y: 1.19480371
# z: -0.984167695
# visibility: 0.212734252
# , W = x: 0.634714186
# y: 1.06260717
# z: -0.478100717
# visibility: 0.0386597402
#
# S.x * w = 0.7373839616775513 * 640 = 471.9257354736328
#
# S.y * h = 1.0360522270202637 * 480 = 497.30506896972656
#
# shoulder = [471.92573547 497.30506897], elbow = [550.97496033 573.50578308], wrist = [406.21707916 510.05144119]
# shoulder - elbow = [-79.04922485 -76.20071411], elbow - wrist = [-144.75788116  -63.45434189]
# hypotenuse (shoulder - elbow) = 109.79676126012993, hypotenuse (elbow - wrist) = 158.05472997321144
# cosang = 0.938017785747291
# theta = 0.35393025372044956
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.14106968
# y: 1.04213142
# z: -1.88201332
# visibility: 0.900117218
# , E = x: 0.0401722826
# y: 1.36215639
# z: -1.38735938
# visibility: 0.421069473
# , W = x: 0.192943186
# y: 1.07227576
# z: -0.772782207
# visibility: 0.0790844411
#
# S.x * w = 0.1410696804523468 * 640 = 90.28459548950195
#
# S.y * h = 1.0421314239501953 * 480 = 500.22308349609375
#
# shoulder = [ 90.28459549 500.2230835 ], elbow = [ 25.71026087 653.83506775], wrist = [123.48363876 514.69236374]
# shoulder - elbow = [  64.57433462 -153.61198425], elbow - wrist = [  97.7733779  -139.14270401]
# hypotenuse (shoulder - elbow) = 166.6327890940295, hypotenuse (elbow - wrist) = 170.05977039760558
# cosang = 0.9770658879910701
# theta = 0.21458012193141898
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.738978744
# y: 1.03646147
# z: -1.7286911
# visibility: 0.829453111
# , E = x: 0.860469937
# y: 1.21817577
# z: -1.04393077
# visibility: 0.205827519
# , W = x: 0.641176403
# y: 1.07807076
# z: -0.484578192
# visibility: 0.0368357897
#
# S.x * w = 0.7389787435531616 * 640 = 472.94639587402344
#
# S.y * h = 1.0364614725112915 * 480 = 497.5015068054199
#
# shoulder = [472.94639587 497.50150681], elbow = [550.70075989 584.72436905], wrist = [410.35289764 517.47396469]
# shoulder - elbow = [-77.75436401 -87.22286224], elbow - wrist = [-140.34786224  -67.25040436]
# hypotenuse (shoulder - elbow) = 116.84848661186294, hypotenuse (elbow - wrist) = 155.62820864412146
# cosang = 0.92265629549041
# theta = 0.3958833201597721
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.141069457
# y: 1.03784144
# z: -1.81982517
# visibility: 0.899640918
# , E = x: 0.042865105
# y: 1.36231
# z: -1.33930504
# visibility: 0.411421508
# , W = x: 0.202272505
# y: 1.0718962
# z: -0.804404438
# visibility: 0.0763225779
#
# S.x * w = 0.1410694569349289 * 640 = 90.28445243835449
#
# S.y * h = 1.0378414392471313 * 480 = 498.16389083862305
#
# shoulder = [ 90.28445244 498.16389084], elbow = [ 27.43366718 653.90882492], wrist = [129.45440292 514.5101738 ]
# shoulder - elbow = [  62.85078526 -155.74493408], elbow - wrist = [ 102.02073574 -139.39865112]
# hypotenuse (shoulder - elbow) = 167.948520990212, hypotenuse (elbow - wrist) = 172.74320380103444
# cosang = 0.9693489052704521
# theta = 0.24822960709157277
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.739089668
# y: 1.03399837
# z: -1.69757903
# visibility: 0.831624627
# , E = x: 0.859675527
# y: 1.21718514
# z: -1.00351572
# visibility: 0.197618246
# , W = x: 0.649675667
# y: 1.0970943
# z: -0.45827198
# visibility: 0.0350445174
#
# S.x * w = 0.7390896677970886 * 640 = 473.0173873901367
#
# S.y * h = 1.0339983701705933 * 480 = 496.31921768188477
#
# shoulder = [473.01738739 496.31921768], elbow = [550.19233704 584.24886703], wrist = [415.79242706 526.60526276]
# shoulder - elbow = [-77.17494965 -87.92964935], elbow - wrist = [-134.39990997  -57.64360428]
# hypotenuse (shoulder - elbow) = 116.99400023312415, hypotenuse (elbow - wrist) = 146.23994296339797
# cosang = 0.9024905826914599
# theta = 0.4452788835121688
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.141032577
# y: 1.03441703
# z: -1.91813636
# visibility: 0.893364787
# , E = x: 0.0461407863
# y: 1.33828282
# z: -1.3485254
# visibility: 0.416389912
# , W = x: 0.203297973
# y: 1.04482496
# z: -0.730825186
# visibility: 0.076417923
#
# S.x * w = 0.14103257656097412 * 640 = 90.26084899902344
#
# S.y * h = 1.0344170331954956 * 480 = 496.5201759338379
#
# shoulder = [ 90.260849   496.52017593], elbow = [ 29.53010321 642.37575531], wrist = [130.11070251 501.51597977]
# shoulder - elbow = [  60.73074579 -145.85557938], elbow - wrist = [ 100.58059931 -140.85977554]
# hypotenuse (shoulder - elbow) = 157.99390343564735, hypotenuse (elbow - wrist) = 173.0836021311818
# cosang = 0.9746715774906513
# theta = 0.22554854073627548
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.740121
# y: 1.03336549
# z: -1.74354768
# visibility: 0.826094747
# , E = x: 0.856624782
# y: 1.1334585
# z: -1.00788069
# visibility: 0.193126947
# , W = x: 0.649518371
# y: 1.0530442
# z: -0.431740671
# visibility: 0.0338202
#
# S.x * w = 0.7401210069656372 * 640 = 473.6774444580078
#
# S.y * h = 1.0333654880523682 * 480 = 496.0154342651367
#
# shoulder = [473.67744446 496.01543427], elbow = [548.23986053 544.06007767], wrist = [415.6917572  505.46121597]
# shoulder - elbow = [-74.56241608 -48.0446434 ], elbow - wrist = [-132.54810333  -38.59886169]
# hypotenuse (shoulder - elbow) = 88.70085485832658, hypotenuse (elbow - wrist) = 138.05387290441303
# cosang = 0.9585217990423915
# theta = 0.2890264889571426
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.14108555
# y: 1.03639388
# z: -1.92652833
# visibility: 0.892913
# , E = x: 0.0482362881
# y: 1.34776318
# z: -1.34317303
# visibility: 0.419011861
# , W = x: 0.203001648
# y: 1.04588521
# z: -0.670065761
# visibility: 0.0745998919
#
# S.x * w = 0.14108555018901825 * 640 = 90.29475212097168
#
# S.y * h = 1.0363938808441162 * 480 = 497.4690628051758
#
# shoulder = [ 90.29475212 497.46906281], elbow = [ 30.8712244  646.92632675], wrist = [129.92105484 502.02489853]
# shoulder - elbow = [  59.42352772 -149.45726395], elbow - wrist = [  99.04983044 -144.90142822]
# hypotenuse (shoulder - elbow) = 160.83727613959292, hypotenuse (elbow - wrist) = 175.52006385030836
# cosang = 0.9756392662900119
# theta = 0.22117996684030514
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.740170896
# y: 1.03321183
# z: -1.74562967
# visibility: 0.823328912
# , E = x: 0.857142925
# y: 1.16448748
# z: -1.01452601
# visibility: 0.190759614
# , W = x: 0.651023686
# y: 1.06311321
# z: -0.441405386
# visibility: 0.03267055
#
# S.x * w = 0.7401708960533142 * 640 = 473.7093734741211
#
# S.y * h = 1.0332118272781372 * 480 = 495.94167709350586
#
# shoulder = [473.70937347 495.94167709], elbow = [548.57147217 558.95399094], wrist = [416.655159   510.29434204]
# shoulder - elbow = [-74.86209869 -63.01231384], elbow - wrist = [-131.91631317  -48.6596489 ]
# hypotenuse (shoulder - elbow) = 97.8513439796541, hypotenuse (elbow - wrist) = 140.60467671508587
# cosang = 0.9406420775886087
# theta = 0.34627915280147187
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.141113564
# y: 1.02687943
# z: -2.01215363
# visibility: 0.891544223
# , E = x: 0.048793029
# y: 1.34724092
# z: -1.34880853
# visibility: 0.413102865
# , W = x: 0.203228503
# y: 1.04705441
# z: -0.626497
# visibility: 0.0725718439
#
# S.x * w = 0.14111356437206268 * 640 = 90.31268119812012
#
# S.y * h = 1.0268794298171997 * 480 = 492.90212631225586
#
# shoulder = [ 90.3126812  492.90212631], elbow = [ 31.22753859 646.67564392], wrist = [130.06624222 502.58611679]
# shoulder - elbow = [  59.08514261 -153.77351761], elbow - wrist = [  98.83870363 -144.08952713]
# hypotenuse (shoulder - elbow) = 164.73417617047352, hypotenuse (elbow - wrist) = 174.7308821239184
# cosang = 0.9726552412339482
# theta = 0.2343941049204011
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.741440535
# y: 1.03192246
# z: -1.87063313
# visibility: 0.825269818
# , E = x: 0.865607738
# y: 1.16754079
# z: -1.10646176
# visibility: 0.18789427
# , W = x: 0.668245
# y: 1.06913269
# z: -0.502640963
# visibility: 0.0316978209
#
# S.x * w = 0.7414405345916748 * 640 = 474.5219421386719
#
# S.y * h = 1.031922459602356 * 480 = 495.32278060913086
#
# shoulder = [474.52194214 495.32278061], elbow = [553.98895264 560.41957855], wrist = [427.67681122 513.18368912]
# shoulder - elbow = [-79.4670105  -65.09679794], elbow - wrist = [-126.31214142  -47.23588943]
# hypotenuse (shoulder - elbow) = 102.7258432041226, hypotenuse (elbow - wrist) = 134.85542748851978
# cosang = 0.9465403356380919
# theta = 0.3284597276381474
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.141499072
# y: 1.04180157
# z: -1.93138242
# visibility: 0.885832489
# , E = x: 0.0511655733
# y: 1.34752512
# z: -1.35035419
# visibility: 0.414948285
# , W = x: 0.203415543
# y: 1.02889764
# z: -0.65008235
# visibility: 0.0707582757
#
# S.x * w = 0.14149907231330872 * 640 = 90.55940628051758
#
# S.y * h = 1.0418015718460083 * 480 = 500.064754486084
#
# shoulder = [ 90.55940628 500.06475449], elbow = [ 32.74596691 646.8120575 ], wrist = [130.18594742 493.87086868]
# shoulder - elbow = [  57.81343937 -146.74730301], elbow - wrist = [  97.43998051 -152.94118881]
# hypotenuse (shoulder - elbow) = 157.72496541535796, hypotenuse (elbow - wrist) = 181.34375379405114
# cosang = 0.9816312887022468
# theta = 0.1919647015335414
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.741465
# y: 1.03195238
# z: -1.80002117
# visibility: 0.813223124
# , E = x: 0.866109669
# y: 1.16965401
# z: -1.0988
# visibility: 0.187052816
# , W = x: 0.660225749
# y: 1.04758298
# z: -0.510359
# visibility: 0.0307357498
#
# S.x * w = 0.7414649724960327 * 640 = 474.53758239746094
#
# S.y * h = 1.0319523811340332 * 480 = 495.33714294433594
#
# shoulder = [474.5375824  495.33714294], elbow = [554.31018829 561.43392563], wrist = [422.54447937 502.83983231]
# shoulder - elbow = [-79.7726059  -66.09678268], elbow - wrist = [-131.76570892  -58.59409332]
# hypotenuse (shoulder - elbow) = 103.59755467543093, hypotenuse (elbow - wrist) = 144.206344601304
# cosang = 0.9628332643205169
# theta = 0.2734932278062354
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.141273677
# y: 1.04157925
# z: -1.80847096
# visibility: 0.891856372
# , E = x: 0.0501343422
# y: 1.34428132
# z: -1.36100113
# visibility: 0.41663149
# , W = x: 0.199801
# y: 1.04111171
# z: -0.89184618
# visibility: 0.0699357688
#
# S.x * w = 0.14127367734909058 * 640 = 90.41515350341797
#
# S.y * h = 1.041579246520996 * 480 = 499.9580383300781
#
# shoulder = [ 90.4151535  499.95803833], elbow = [ 32.08597898 645.25503159], wrist = [127.8726387  499.73361969]
# shoulder - elbow = [  58.32917452 -145.29699326], elbow - wrist = [  95.78665972 -145.5214119 ]
# hypotenuse (shoulder - elbow) = 156.56790492394418, hypotenuse (elbow - wrist) = 174.21700692947584
# cosang = 0.9799898980955449
# theta = 0.20038559995923277
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.741849
# y: 1.02873969
# z: -1.6003269
# visibility: 0.819263875
# , E = x: 0.865626037
# y: 1.16135943
# z: -0.944968522
# visibility: 0.184803322
# , W = x: 0.661433339
# y: 1.04885209
# z: -0.441697121
# visibility: 0.0294494051
#
# S.x * w = 0.7418490052223206 * 640 = 474.78336334228516
#
# S.y * h = 1.0287396907806396 * 480 = 493.79505157470703
#
# shoulder = [474.78336334 493.79505157], elbow = [554.00066376 557.45252609], wrist = [423.31733704 503.44900131]
# shoulder - elbow = [-79.21730042 -63.65747452], elbow - wrist = [-130.68332672  -54.00352478]
# hypotenuse (shoulder - elbow) = 101.62506949107704, hypotenuse (elbow - wrist) = 141.40195392723294
# cosang = 0.9596467843109753
# theta = 0.28505287786158445
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.146183282
# y: 1.05775213
# z: -1.79551542
# visibility: 0.893407762
# , E = x: 0.0519634783
# y: 1.34429467
# z: -1.4757098
# visibility: 0.423249364
# , W = x: 0.216695905
# y: 1.04146612
# z: -1.12459207
# visibility: 0.068977043
#
# S.x * w = 0.14618328213691711 * 640 = 93.55730056762695
#
# S.y * h = 1.0577521324157715 * 480 = 507.7210235595703
#
# shoulder = [ 93.55730057 507.72102356], elbow = [ 33.25662613 645.26144028], wrist = [138.68537903 499.90373611]
# shoulder - elbow = [  60.30067444 -137.54041672], elbow - wrist = [ 105.4287529  -145.35770416]
# hypotenuse (shoulder - elbow) = 150.1783525398062, hypotenuse (elbow - wrist) = 179.56637798008518
# cosang = 0.9771202172622996
# theta = 0.21432483017507423
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.74052453
# y: 1.02858579
# z: -1.59965301
# visibility: 0.815395057
# , E = x: 0.843466
# y: 1.16077
# z: -0.954844356
# visibility: 0.186813727
# , W = x: 0.638422608
# y: 1.0404613
# z: -0.445704222
# visibility: 0.0290513318
#
# S.x * w = 0.7405245304107666 * 640 = 473.9356994628906
#
# S.y * h = 1.0285857915878296 * 480 = 493.7211799621582
#
# shoulder = [473.93569946 493.72117996], elbow = [539.81822968 557.16962814], wrist = [408.59046936 499.42142487]
# shoulder - elbow = [-65.88253021 -63.44844818], elbow - wrist = [-131.22776031  -57.74820328]
# hypotenuse (shoulder - elbow) = 91.4670069785484, hypotenuse (elbow - wrist) = 143.37217324827287
# cosang = 0.9386774726832329
# theta = 0.352021944794749
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.15739879
# y: 1.05754864
# z: -1.40765262
# visibility: 0.901497364
# , E = x: 0.0493040159
# y: 1.34435081
# z: -1.27418768
# visibility: 0.437324941
# , W = x: 0.240674257
# y: 1.04179776
# z: -0.657050133
# visibility: 0.0723456293
#
# S.x * w = 0.1573987901210785 * 640 = 100.73522567749023
#
# S.y * h = 1.0575486421585083 * 480 = 507.623348236084
#
# shoulder = [100.73522568 507.62334824], elbow = [ 31.5545702  645.28839111], wrist = [154.03152466 500.06292343]
# shoulder - elbow = [  69.18065548 -137.66504288], elbow - wrist = [ 122.47695446 -145.22546768]
# hypotenuse (shoulder - elbow) = 154.0702019406274, hypotenuse (elbow - wrist) = 189.97642180295398
# cosang = 0.9725245120600237
# theta = 0.23495631538863807
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.739150822
# y: 1.02855802
# z: -1.12088442
# visibility: 0.821244776
# , E = x: 0.852781177
# y: 1.16145837
# z: -0.580512464
# visibility: 0.193561688
# , W = x: 0.633428156
# y: 1.02118778
# z: 0.333550334
# visibility: 0.0310298614
#
# S.x * w = 0.7391508221626282 * 640 = 473.05652618408203
#
# S.y * h = 1.0285580158233643 * 480 = 493.70784759521484
#
# shoulder = [473.05652618 493.7078476 ], elbow = [545.779953   557.50001907], wrist = [405.39402008 490.1701355 ]
# shoulder - elbow = [-72.72342682 -63.79217148], elbow - wrist = [-140.38593292  -67.32988358]
# hypotenuse (shoulder - elbow) = 96.73746922534325, hypotenuse (elbow - wrist) = 155.69689588388863
# cosang = 0.9630017063002122
# theta = 0.2728688966573991
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.15798828
# y: 1.05320561
# z: -1.77042902
# visibility: 0.89755553
# , E = x: 0.0522972941
# y: 1.33644438
# z: -1.34062696
# visibility: 0.44562611
# , W = x: 0.238546684
# y: 1.03371668
# z: -0.783249259
# visibility: 0.0757473484
#
# S.x * w = 0.1579882800579071 * 640 = 101.11249923706055
#
# S.y * h = 1.0532056093215942 * 480 = 505.53869247436523
#
# ...
#
# S.x * w = 0.183767169713974 * 640 = 117.61098861694336
#
# S.y * h = 1.0367528200149536 * 480 = 497.64135360717773
#
# shoulder = [117.61098862 497.64135361], elbow = [ 48.92368793 664.64355469], wrist = [166.60531998 501.80002213]
# shoulder - elbow = [  68.68730068 -167.00220108], elbow - wrist = [ 117.68163204 -162.84353256]
# hypotenuse (shoulder - elbow) = 180.5759686233822, hypotenuse (elbow - wrist) = 200.91536183533918
# cosang = 0.9723811842471686
# theta = 0.23557119369546606
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.755294442
# y: 1.12498581
# z: -1.82783318
# visibility: 0.711452484
# , E = x: 0.859714389
# y: 1.26936746
# z: -1.44544291
# visibility: 0.235138118
# , W = x: 0.63658607
# y: 1.08896756
# z: -1.11016643
# visibility: 0.0812007114
#
# S.x * w = 0.7552944421768188 * 640 = 483.38844299316406
#
# S.y * h = 1.1249858140945435 * 480 = 539.9931907653809
#
# shoulder = [483.38844299 539.99319077], elbow = [550.21720886 609.29637909], wrist = [407.41508484 522.70442963]
# shoulder - elbow = [-66.82876587 -69.30318832], elbow - wrist = [-142.80212402  -86.59194946]
# hypotenuse (shoulder - elbow) = 96.27572830878101, hypotenuse (elbow - wrist) = 167.00482729768362
# cosang = 0.9667802899394237
# theta = 0.2584773948993608
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.182756931
# y: 1.04219806
# z: -1.69674277
# visibility: 0.73075515
# , E = x: 0.0748310387
# y: 1.38586962
# z: -1.44588125
# visibility: 0.380235612
# , W = x: 0.260602772
# y: 1.046229
# z: -1.24478114
# visibility: 0.13038373
#
# S.x * w = 0.1827569305896759 * 640 = 116.96443557739258
#
# S.y * h = 1.0421980619430542 * 480 = 500.255069732666
#
# shoulder = [116.96443558 500.25506973], elbow = [ 47.89186478 665.21741867], wrist = [166.78577423 502.18992233]
# shoulder - elbow = [  69.0725708  -164.96234894], elbow - wrist = [ 118.89390945 -163.02749634]
# hypotenuse (shoulder - elbow) = 178.83958344769297, hypotenuse (elbow - wrist) = 201.7764264515918
# cosang = 0.9728449849015492
# theta = 0.23357573519985678
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.755202
# y: 1.19375229
# z: -1.76024663
# visibility: 0.69437772
# , E = x: 0.850781798
# y: 1.30940127
# z: -1.4452399
# visibility: 0.229103982
# , W = x: 0.636255383
# y: 1.09642541
# z: -1.18737352
# visibility: 0.0795520768
#
# S.x * w = 0.7552019953727722 * 640 = 483.3292770385742
#
# S.y * h = 1.1937522888183594 * 480 = 573.0010986328125
#
# shoulder = [483.32927704 573.00109863], elbow = [544.50035095 628.51261139], wrist = [407.20344543 526.28419876]
# shoulder - elbow = [-61.17107391 -55.51151276], elbow - wrist = [-137.29690552 -102.22841263]
# hypotenuse (shoulder - elbow) = 82.60404550559366, hypotenuse (elbow - wrist) = 171.17560753974982
# cosang = 0.9953079464786688
# theta = 0.0969095180770662
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.18213062
# y: 1.03997648
# z: -1.70983255
# visibility: 0.73129946
# , E = x: 0.0926155895
# y: 1.35084236
# z: -1.44342053
# visibility: 0.378198564
# , W = x: 0.271398336
# y: 1.02211487
# z: -1.20588648
# visibility: 0.128268138
#
# S.x * w = 0.1821306198835373 * 640 = 116.56359672546387
#
# S.y * h = 1.0399764776229858 * 480 = 499.1887092590332
#
# shoulder = [116.56359673 499.18870926], elbow = [ 59.27397728 648.40433121], wrist = [173.69493484 490.61513901]
# shoulder - elbow = [  57.28961945 -149.21562195], elbow - wrist = [ 114.42095757 -157.7891922 ]
# hypotenuse (shoulder - elbow) = 159.8355477759629, hypotenuse (elbow - wrist) = 194.909170407901
# cosang = 0.9661780743599369
# theta = 0.26082299698418165
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.764389157
# y: 1.19172204
# z: -1.74896395
# visibility: 0.699109375
# , E = x: 0.851492047
# y: 1.21212304
# z: -1.36766648
# visibility: 0.22831589
# , W = x: 0.63375932
# y: 1.05741572
# z: -0.99415797
# visibility: 0.0782269
#
# S.x * w = 0.764389157295227 * 640 = 489.2090606689453
#
# S.y * h = 1.19172203540802 * 480 = 572.0265769958496
#
# shoulder = [489.20906067 572.026577  ], elbow = [544.95491028 581.81905746], wrist = [405.60596466 507.55954742]
# shoulder - elbow = [-55.74584961  -9.79248047], elbow - wrist = [-139.34894562  -74.25951004]
# hypotenuse (shoulder - elbow) = 56.59940303160355, hypotenuse (elbow - wrist) = 157.90061266296246
# cosang = 0.9505688404696525
# theta = 0.31573360404798767
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.179307848
# y: 1.04169238
# z: -1.70863461
# visibility: 0.728210509
# , E = x: 0.0920175239
# y: 1.36152828
# z: -1.35290277
# visibility: 0.372456044
# , W = x: 0.268285722
# y: 1.0241611
# z: -1.05982959
# visibility: 0.125539258
#
# S.x * w = 0.17930784821510315 * 640 = 114.75702285766602
#
# S.y * h = 1.0416923761367798 * 480 = 500.0123405456543
#
# shoulder = [114.75702286 500.01234055], elbow = [ 58.89121532 653.53357315], wrist = [171.70286179 491.59732819]
# shoulder - elbow = [  55.86580753 -153.5212326 ], elbow - wrist = [ 112.81164646 -161.93624496]
# hypotenuse (shoulder - elbow) = 163.37000127062385, hypotenuse (elbow - wrist) = 197.35707490367162
# cosang = 0.9665265067989667
# theta = 0.2594683953239881
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.762159228
# y: 1.13479173
# z: -1.74054873
# visibility: 0.696926355
# , E = x: 0.85498
# y: 1.21916521
# z: -1.3355186
# visibility: 0.224617258
# , W = x: 0.634285927
# y: 1.05871761
# z: -0.948898
# visibility: 0.0760441497
#
# S.x * w = 0.7621592283248901 * 640 = 487.7819061279297
#
# S.y * h = 1.1347917318344116 * 480 = 544.7000312805176
#
# shoulder = [487.78190613 544.70003128], elbow = [547.18719482 585.19929886], wrist = [405.94299316 508.18445206]
# shoulder - elbow = [-59.4052887  -40.49926758], elbow - wrist = [-141.24420166  -77.0148468 ]
# hypotenuse (shoulder - elbow) = 71.89700272537065, hypotenuse (elbow - wrist) = 160.87638463656074
# cosang = 0.9950864778878002
# theta = 0.09917208454047631
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.178518787
# y: 1.04165494
# z: -1.77331674
# visibility: 0.727153361
# , E = x: 0.0918266
# y: 1.35904646
# z: -1.43343544
# visibility: 0.373746
# , W = x: 0.268968284
# y: 1.02316391
# z: -1.12183189
# visibility: 0.12596269
#
# S.x * w = 0.17851878702640533 * 640 = 114.25202369689941
#
# S.y * h = 1.0416549444198608 * 480 = 499.9943733215332
#
# shoulder = [114.2520237  499.99437332], elbow = [ 58.7690258  652.34230042], wrist = [172.13970184 491.11867905]
# shoulder - elbow = [  55.48299789 -152.34792709], elbow - wrist = [ 113.37067604 -161.22362137]
# hypotenuse (shoulder - elbow) = 162.1365287289338, hypotenuse (elbow - wrist) = 197.0938007066676
# cosang = 0.9654565161310167
# theta = 0.2636065697287513
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.766248345
# y: 1.15252948
# z: -1.76761889
# visibility: 0.694767118
# , E = x: 0.852337241
# y: 1.22328937
# z: -1.38327444
# visibility: 0.223905385
# , W = x: 0.626577497
# y: 1.05757844
# z: -1.00660717
# visibility: 0.0757094324
#
# S.x * w = 0.766248345375061 * 640 = 490.39894104003906
#
# S.y * h = 1.1525294780731201 * 480 = 553.2141494750977
#
# shoulder = [490.39894104 553.21414948], elbow = [545.49583435 587.17889786], wrist = [401.00959778 507.63765335]
# shoulder - elbow = [-55.09689331 -33.96474838], elbow - wrist = [-144.48623657  -79.54124451]
# hypotenuse (shoulder - elbow) = 64.72458409645793, hypotenuse (elbow - wrist) = 164.93356886883774
# cosang = 0.9987901432228183
# theta = 0.04919554481503219
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.178524122
# y: 1.04302704
# z: -1.7715832
# visibility: 0.723397076
# , E = x: 0.0976787955
# y: 1.33342767
# z: -1.52764487
# visibility: 0.372441739
# , W = x: 0.281291902
# y: 1.00421405
# z: -1.3362211
# visibility: 0.123583503
#
# S.x * w = 0.17852412164211273 * 640 = 114.25543785095215
#
# S.y * h = 1.0430270433425903 * 480 = 500.65298080444336
#
# shoulder = [114.25543785 500.6529808 ], elbow = [ 62.51442909 640.04528046], wrist = [180.02681732 482.02274323]
# shoulder - elbow = [  51.74100876 -139.39229965], elbow - wrist = [ 117.51238823 -158.02253723]
# hypotenuse (shoulder - elbow) = 148.68538997704604, hypotenuse (elbow - wrist) = 196.92710241196428
# cosang = 0.959943944057981
# theta = 0.2839942403412113
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.765918374
# y: 1.15041125
# z: -1.75876451
# visibility: 0.692713797
# , E = x: 0.850138
# y: 1.20784914
# z: -1.39432645
# visibility: 0.222650945
# , W = x: 0.626054645
# y: 1.04571426
# z: -1.03796852
# visibility: 0.074152
#
# S.x * w = 0.7659183740615845 * 640 = 490.18775939941406
#
# S.y * h = 1.1504112482070923 * 480 = 552.1973991394043
#
# shoulder = [490.1877594  552.19739914], elbow = [544.0883255  579.76758957], wrist = [400.67497253 501.94284439]
# shoulder - elbow = [-53.9005661  -27.57019043], elbow - wrist = [-143.41335297  -77.82474518]
# hypotenuse (shoulder - elbow) = 60.54243493250294, hypotenuse (elbow - wrist) = 163.16887195282587
# cosang = 0.9997027063513405
# theta = 0.024384764932761097
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.178510964
# y: 1.04583275
# z: -1.63249838
# visibility: 0.71259743
# , E = x: 0.0870005339
# y: 1.33464873
# z: -1.51785922
# visibility: 0.366220772
# , W = x: 0.278675586
# y: 1.00305164
# z: -1.27560699
# visibility: 0.121830247
#
# S.x * w = 0.17851096391677856 * 640 = 114.24701690673828
#
# S.y * h = 1.0458327531814575 * 480 = 501.9997215270996
#
# shoulder = [114.24701691 501.99972153], elbow = [ 55.68034172 640.63138962], wrist = [178.35237503 481.46478653]
# shoulder - elbow = [  58.56667519 -138.63166809], elbow - wrist = [ 122.67203331 -159.16660309]
# hypotenuse (shoulder - elbow) = 150.49516551376033, hypotenuse (elbow - wrist) = 200.9538138456367
# cosang = 0.9671802889039316
# theta = 0.2569078483450848
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.762680292
# y: 1.18755412
# z: -1.6165669
# visibility: 0.67809093
# , E = x: 0.841790378
# y: 1.29238808
# z: -1.33687043
# visibility: 0.217187166
# , W = x: 0.626046479
# y: 1.07793939
# z: -1.03970146
# visibility: 0.0731203631
#
# S.x * w = 0.7626802921295166 * 640 = 488.1153869628906
#
# S.y * h = 1.187554121017456 * 480 = 570.0259780883789
#
# shoulder = [488.11538696 570.02597809], elbow = [538.74584198 620.34627914], wrist = [400.6697464  517.41090775]
# shoulder - elbow = [-50.63045502 -50.32030106], elbow - wrist = [-138.07609558 -102.9353714 ]
# hypotenuse (shoulder - elbow) = 71.38330109362035, hypotenuse (elbow - wrist) = 172.222817476047
# cosang = 0.9899755586089352
# theta = 0.14171262854453395
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.17866084
# y: 1.04203558
# z: -1.71972179
# visibility: 0.71380645
# , E = x: 0.101000592
# y: 1.32683551
# z: -1.39074719
# visibility: 0.365957558
# , W = x: 0.276982039
# y: 0.997201
# z: -1.03525567
# visibility: 0.120914698
#
# S.x * w = 0.17866083979606628 * 640 = 114.34293746948242
#
# S.y * h = 1.0420355796813965 * 480 = 500.1770782470703
#
# shoulder = [114.34293747 500.17707825], elbow = [ 64.64037895 636.8810463 ], wrist = [177.2685051  478.65649223]
# shoulder - elbow = [  49.70255852 -136.70396805], elbow - wrist = [ 112.62812614 -158.22455406]
# hypotenuse (shoulder - elbow) = 145.45899493047892, hypotenuse (elbow - wrist) = 194.2166427234523
# cosang = 0.9637979806021622
# theta = 0.2698984401425794
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.755397797
# y: 1.10559201
# z: -1.6784395
# visibility: 0.681479633
# , E = x: 0.843796551
# y: 1.22855365
# z: -1.32738543
# visibility: 0.21684584
# , W = x: 0.625881791
# y: 1.05753934
# z: -0.993439555
# visibility: 0.0718868
#
# S.x * w = 0.7553977966308594 * 640 = 483.45458984375
#
# S.y * h = 1.1055920124053955 * 480 = 530.6841659545898
#
# shoulder = [483.45458984 530.68416595], elbow = [540.02979279 589.70575333], wrist = [400.56434631 507.61888504]
# shoulder - elbow = [-56.57520294 -59.02158737], elbow - wrist = [-139.46544647  -82.08686829]
# hypotenuse (shoulder - elbow) = 81.75757680754617, hypotenuse (elbow - wrist) = 161.82973987479144
# cosang = 0.9625401408344791
# theta = 0.27457639161127956
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.17979756
# y: 1.0430156
# z: -1.67816
# visibility: 0.707910061
# , E = x: 0.0975438803
# y: 1.33174765
# z: -1.39240587
# visibility: 0.360865563
# , W = x: 0.279199958
# y: 0.999446511
# z: -1.15472746
# visibility: 0.118806966
#
# S.x * w = 0.17979755997657776 * 640 = 115.07043838500977
#
# S.y * h = 1.0430155992507935 * 480 = 500.64748764038086
#
# shoulder = [115.07043839 500.64748764], elbow = [ 62.42808342 639.23887253], wrist = [178.68797302 479.73432541]
# shoulder - elbow = [  52.64235497 -138.59138489], elbow - wrist = [ 116.2598896  -159.50454712]
# hypotenuse (shoulder - elbow) = 148.25245193364432, hypotenuse (elbow - wrist) = 197.37796859338852
# cosang = 0.9646085174735248
# theta = 0.2668416569678281
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.758644462
# y: 1.13460028
# z: -1.66975439
# visibility: 0.671380639
# , E = x: 0.844012439
# y: 1.22890294
# z: -1.32950139
# visibility: 0.212258384
# , W = x: 0.626131415
# y: 1.05759752
# z: -0.993496537
# visibility: 0.0700132549
#
# S.x * w = 0.7586444616317749 * 640 = 485.53245544433594
#
# S.y * h = 1.134600281715393 * 480 = 544.6081352233887
#
# shoulder = [485.53245544 544.60813522], elbow = [540.16796112 589.87340927], wrist = [400.72410583 507.64680862]
# shoulder - elbow = [-54.63550568 -45.26527405], elbow - wrist = [-139.44385529  -82.22660065]
# hypotenuse (shoulder - elbow) = 70.95057093884301, hypotenuse (elbow - wrist) = 161.88206396669813
# cosang = 0.9873729374209264
# theta = 0.15908316195292965
# L.RIGHT_SHOULDER.value = 12, L.RIGHT_ELBOW.value = 14, L.RIGHT_WRIST.value = 16
# 3D Coordinates and Visibility of Landmarks: S = x: 0.179675207
# y: 1.04536498
# z: -1.6808393
# visibility: 0.69036895
# , E = x: 0.0838383585
# y: 1.36141014
# z: -1.39097321
# visibility: 0.345610857
# , W = x: 0.263902545
# y: 1.00976884
# z: -1.13282621
# visibility: 0.112188667
#
# S.x * w = 0.17967520654201508 * 640 = 114.99213218688965
#
# S.y * h = 1.0453649759292603 * 480 = 501.7751884460449
#
# shoulder = [114.99213219 501.77518845], elbow = [ 53.65654945 653.47686768], wrist = [168.89762878 484.68904495]
# shoulder - elbow = [  61.33558273 -151.70167923], elbow - wrist = [ 115.24107933 -168.78782272]
# hypotenuse (shoulder - elbow) = 163.63206652001335, hypotenuse (elbow - wrist) = 204.37669991717593
# cosang = 0.9770111391100688
# theta = 0.21483708325417727
# L.LEFT_SHOULDER.value = 11, L.LEFT_ELBOW.value = 13, L.LEFT_WRIST.value = 15
# 3D Coordinates and Visibility of Landmarks: S = x: 0.751644075
# y: 1.11195195
# z: -1.74692857
# visibility: 0.65517664
# , E = x: 0.856340587
# y: 1.2627579
# z: -1.47485435
# visibility: 0.204292178
# , W = x: 0.630870521
# y: 1.06911612
# z: -1.16342902
# visibility: 0.0668019205
#
# S.x * w = 0.7516440749168396 * 640 = 481.05220794677734
#
# S.y * h = 1.1119519472122192 * 480 = 533.7369346618652
#
# shoulder = [481.05220795 533.73693466], elbow = [548.05797577 606.12379074], wrist = [403.75713348 513.17573547]
# shoulder - elbow = [-67.00576782 -72.38685608], elbow - wrist = [-144.30084229  -92.94805527]
# hypotenuse (shoulder - elbow) = 98.63888612733169, hypotenuse (elbow - wrist) = 171.64519820145804
# cosang = 0.9684786275880224
# theta = 0.2517474057115706
